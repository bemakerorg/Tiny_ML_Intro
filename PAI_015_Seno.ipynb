# %% [markdown]
# <a href="https://colab.research.google.com/github/bemakerorg/Tiny_ML_Intro/blob/main/PAI_015_Seno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
x_values = np.linspace(0,2 * math.pi,1000)
y_values = np.sin(x_values)
plt.plot(x_values, y_values, 'r')
